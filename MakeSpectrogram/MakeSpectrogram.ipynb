# %%
from scipy.io import wavfile
import matplotlib.pyplot as plt
import numpy as np

# %%
"10406.wav"
# Out:
# '10406.wav'

# %%
# Read the wav file (mono)

samplingFrequency, signalData = wavfile.read("10406.wav")

# Plot the signal read from wav file
plt.figure(figsize=(10,10))
plt.subplot(211)

plt.title('Spectrogram of a wav file with piano music')

 

plt.plot(signalData)

plt.xlabel('Sample')

plt.ylabel('Amplitude')

 

plt.subplot(212)

plt.specgram(signalData[:,1],Fs=samplingFrequency)

plt.xlabel('Time')

plt.ylabel('Frequency')

 

plt.show()

# %%
signalData[:,1]
# Out:
# array([ 17, -17, -32, ...,  31,  81,  79], dtype=int16)

# %%
# ?plt.specgram

# %%
signalData
# Out:
# array([[ 17,  17],
#        [-17, -17],
#        [-32, -32],
#        ...,
#        [ 31,  31],
#        [ 81,  81],
#        [ 79,  79]], dtype=int16)

# %%
print(signalData.size)
print(signalData.ndim)
# Out:
# 10681856
# 2

# %%
len(signalData)
# Out:
# 5340928

# %%
samplingFrequency
# Out:
# 44100

# %%
len(signalData)/samplingFrequency
# Out:
# 121.10947845804989

# %%
# ?np.amax

# %%
signalData.max(axis = None)
# Out:
# 1913

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-7d06ba0dc95b> in <module>
# ----> 1 a.type
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'type'

# %%
type(a)
# Out:
# builtin_function_or_method

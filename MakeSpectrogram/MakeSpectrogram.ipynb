# %%
from scipy.io import wavfile
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read the wav file (mono)

samplingFrequency, signalData = wavfile.read("PardalRaven.wav")

# Plot the signal read from wav file
plt.figure(figsize=(10,10))



plt.title('Spectrogram of wav files with bird calls')


plt.specgram(signalData[:,1],Fs=samplingFrequency)

plt.xlabel('Time')

plt.ylabel('Frequency - PardalRaven')
# Out:
# Text(0, 0.5, 'Frequency - PardalRaven')

# %%
# ?plt.specgram

# %%
len(signalData)
# Out:
# 441000

# %%
samplingFrequency, signalData = wavfile.read("PardalRaven.wav")
len(signalData)
# Out:
# 441000

# %%
samplingFrequency
# Out:
# 44100

# %%
signalData
# Out:
# array([[-539, -539],
#        [ 145,  144],
#        [ 777,  780],
#        ...,
#        [ 162,  160],
#        [ 125,  126],
#        [  92,   90]], dtype=int16)

# %%
arrSignalDelta = signalData[:,0] - signalData[:,1]

# %%
arrSignalDelta
# Out:
# array([ 0,  1, -3, ...,  2, -1,  2], dtype=int16)

# %%
arrSignalDelta.mean()
# Out:
# 0.0003310657596371882

# %%
signalData[:,0].min()
# Out:
# -4970
